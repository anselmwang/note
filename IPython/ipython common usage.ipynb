# %% [raw]
# press h to get help at command mode

# %% [markdown]
# # Draw

# %% [raw]
# The old %matplotlib inline activates the inline backend, which renders figures in the notebook as static pngs.
# The new %matplotlib notebook activates the nbagg backend, added in matplotlib 1.4, which will include a javascript interface for interaction with inline figures in the notebook. This only works in IPython 3.x; for older IPython versions, use %matplotlib nbagg

# %%
# %matplotlib notebook
import Imp

# %%
Imp.plt.plot([1,2], [2,3])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Time it

# %%
# %time  x=range(1000)    
z = max(x)
print z
# Out:
# Wall time: 0 ns
# 999

# %%
# %timeit x=range(1000)    
z = max(x)
print z
# Out:
# 100000 loops, best of 3: 5.63 µs per loop
# 999

# %% [markdown]
# # Shell

# %%
# %cd d:\temp
# Out:
# d:\temp

# %%
lines = !ls -l | grep a

# %%
lines.grep("ab")
# Out:
# ['drwxr-xr-x    1 yuwan    Administ        0 Apr 13 13:30 abc']

# %% [markdown]
# We can even use wget inside the script, which is very fancy

# %% [markdown]
# # Math

# %% [markdown]
# How to type latex, just follow
# http://stackoverflow.com/questions/13208286/how-to-write-latex-in-ipython-notebook
#
# Typical way is to use markdown.
#
# $$\frac{A}{B} = sin(A)$$
